# %% [markdown]
# Connect with databse postgres online

# %%
# %pip install flask pandas sqlalchemy psycopg2 keplergl matplotlib
# Out:
# Requirement already satisfied: flask in c:\users\tan kai jian\appdata\local\programs\python\python311\lib\site-packages (3.1.0)
# Requirement already satisfied: pandas in c:\users\tan kai jian\appdata\local\programs\python\python311\lib\site-packages (2.2.3)
# Requirement already satisfied: sqlalchemy in c:\users\tan kai jian\appdata\local\programs\python\python311\lib\site-packages (2.0.40)
# Requirement already satisfied: psycopg2 in c:\users\tan kai jian\appdata\local\programs\python\python311\lib\site-packages (2.9.10)
# Requirement already satisfied: keplergl in c:\users\tan kai jian\appdata\local\programs\python\python311\lib\site-packages (0.3.7)
# Requirement already satisfied: matplotlib in c:\users\tan kai jian\appdata\local\programs\python\python311\lib\site-packages (3.10.1)
# Requirement already satisfied: Werkzeug>=3.1 in c:\users\tan kai jian\appdata\local\programs\python\python311\lib\site-packages (from flask) (3.1.3)
# Requirement already satisfied: Jinja2>=3.1.2 in c:\users\tan kai jian\appdata\local\programs\python\python311\lib\site-packages (from flask) (3.1.6)
# Requirement already satisfied: itsdangerous>=2.2 in c:\users\tan kai jian\appdata\local\programs\python\python311\lib\site-packages (from flask) (2.2.0)
# Requirement already satisfied: click>=8.1.3 in c:\users\tan kai jian\appdata\local\programs\python\python311\lib\site-packages (from flask) (8.1.8)
# Requirement already satisfied: blinker>=1.9 in c:\users\tan kai jian\appdata\local\programs\python\python311\lib\site-packages (from flask) (1.9.0)
# Requirement already satisfied: numpy>=1.23.2 in c:\users\tan kai jian\appdata\local\programs\python\python311\lib\site-packages (from pandas) (2.2.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\tan kai jian\appdata\roaming\python\python311\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\tan kai jian\appdata\local\programs\python\python311\lib\site-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\tan kai jian\appdata\local\programs\python\python311\lib\site-packages (from pandas) (2025.2)
# Requirement already satisfied: greenlet>=1 in c:\users\tan kai jian\appdata\local\programs\python\python311\lib\site-packages (from sqlalchemy) (3.1.1)
# Requirement already satisfied: typing-extensions>=4.6.0 in c:\users\tan kai jian\appdata\roaming\python\python311\site-packages (from sqlalchemy) (4.13.2)
# Requirement already satisfied: ipywidgets>=8.1.5 in c:\users\tan kai jian\appdata\local\programs\python\python311\lib\site-packages (from keplergl) (8.1.6)
# Requirement already satisfied: traittypes>=0.2.1 in c:\users\tan kai jian\appdata\local\programs\python\python311\lib\site-packages (from keplergl) (0.2.1)
# Requirement already satisfied: traitlets>=4.3.2 in c:\users\tan kai jian\appdata\roaming\python\python311\site-packages (from keplergl) (5.14.3)
# Requirement already satisfied: geopandas>=0.14.3 in c:\users\tan kai jian\appdata\local\programs\python\python311\lib\site-packages (from keplergl) (1.0.1)
# Requirement already satisfied: Shapely>=1.6.4.post2 in c:\users\tan kai jian\appdata\local\programs\python\python311\lib\site-packages (from keplergl) (2.1.0)
# Requirement already satisfied: jupyter_packaging>=0.12.3 in c:\users\tan kai jian\appdata\local\programs\python\python311\lib\site-packages (from keplergl) (0.12.3)
# Requirement already satisfied: jupyter>=1.0.0 in c:\users\tan kai jian\appdata\local\programs\python\python311\lib\site-packages (from keplergl) (1.1.1)
# Requirement already satisfied: jupyterlab>=4.1.6 in c:\users\tan kai jian\appdata\local\programs\python\python311\lib\site-packages (from keplergl) (4.4.0)
# Requirement already satisfied: notebook>=6.0.1 in c:\users\tan kai jian\appdata\local\programs\python\python311\lib\site-packages (from keplergl) (7.4.0)
# Requirement already satisfied: pyarrow>=16.0.0 in c:\users\tan kai jian\appdata\local\programs\python\python311\lib\site-packages (from keplergl) (19.0.1)
# Requirement already satisfied: geoarrow-pyarrow>=0.1.2 in c:\users\tan kai jian\appdata\local\programs\python\python311\lib\site-packages (from keplergl) (0.1.2)
# Requirement already satisfied: geoarrow-pandas>=0.1.1 in c:\users\tan kai jian\appdata\local\programs\python\python311\lib\site-packages (from keplergl) (0.1.1)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\tan kai jian\appdata\local\programs\python\python311\lib\site-packages (from matplotlib) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\tan kai jian\appdata\local\programs\python\python311\lib\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\tan kai jian\appdata\local\programs\python\python311\lib\site-packages (from matplotlib) (4.57.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\tan kai jian\appdata\local\programs\python\python311\lib\site-packages (from matplotlib) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in c:\users\tan kai jian\appdata\roaming\python\python311\site-packages (from matplotlib) (24.2)
# Requirement already satisfied: pillow>=8 in c:\users\tan kai jian\appdata\local\programs\python\python311\lib\site-packages (from matplotlib) (11.1.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\tan kai jian\appdata\local\programs\python\python311\lib\site-packages (from matplotlib) (3.2.3)
# Requirement already satisfied: colorama in c:\users\tan kai jian\appdata\roaming\python\python311\site-packages (from click>=8.1.3->flask) (0.4.6)
# Requirement already satisfied: geoarrow-c in c:\users\tan kai jian\appdata\local\programs\python\python311\lib\site-packages (from geoarrow-pyarrow>=0.1.2->keplergl) (0.1.2)
# Requirement already satisfied: pyarrow-hotfix in c:\users\tan kai jian\appdata\local\programs\python\python311\lib\site-packages (from geoarrow-pyarrow>=0.1.2->keplergl) (0.6)
# Requirement already satisfied: pyogrio>=0.7.2 in c:\users\tan kai jian\appdata\local\programs\python\python311\lib\site-packages (from geopandas>=0.14.3->keplergl) (0.10.0)
# Requirement already satisfied: pyproj>=3.3.0 in c:\users\tan kai jian\appdata\local\programs\python\python311\lib\site-packages (from geopandas>=0.14.3->keplergl) (3.7.1)
# Requirement already satisfied: comm>=0.1.3 in c:\users\tan kai jian\appdata\roaming\python\python311\site-packages (from ipywidgets>=8.1.5->keplergl) (0.2.2)
# Requirement already satisfied: ipython>=6.1.0 in c:\users\tan kai jian\appdata\roaming\python\python311\site-packages (from ipywidgets>=8.1.5->keplergl) (9.1.0)
# Requirement already satisfied: widgetsnbextension~=4.0.14 in c:\users\tan kai jian\appdata\local\programs\python\python311\lib\site-packages (from ipywidgets>=8.1.5->keplergl) (4.0.14)
# Requirement already satisfied: jupyterlab_widgets~=3.0.14 in c:\users\tan kai jian\appdata\local\programs\python\python311\lib\site-packages (from ipywidgets>=8.1.5->keplergl) (3.0.14)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\tan kai jian\appdata\local\programs\python\python311\lib\site-packages (from Jinja2>=3.1.2->flask) (3.0.2)
# Requirement already satisfied: jupyter-console in c:\users\tan kai jian\appdata\local\programs\python\python311\lib\site-packages (from jupyter>=1.0.0->keplergl) (6.6.3)
# Requirement already satisfied: nbconvert in c:\users\tan kai jian\appdata\local\programs\python\python311\lib\site-packages (from jupyter>=1.0.0->keplergl) (7.16.6)
# Requirement already satisfied: ipykernel in c:\users\tan kai jian\appdata\roaming\python\python311\site-packages (from jupyter>=1.0.0->keplergl) (6.29.5)
# Requirement already satisfied: deprecation in c:\users\tan kai jian\appdata\local\programs\python\python311\lib\site-packages (from jupyter_packaging>=0.12.3->keplergl) (2.1.0)
# Requirement already satisfied: setuptools>=60.2.0 in c:\users\tan kai jian\appdata\local\programs\python\python311\lib\site-packages (from jupyter_packaging>=0.12.3->keplergl) (65.5.0)
# Requirement already satisfied: tomlkit in c:\users\tan kai jian\appdata\local\programs\python\python311\lib\site-packages (from jupyter_packaging>=0.12.3->keplergl) (0.13.2)
# Requirement already satisfied: wheel in c:\users\tan kai jian\appdata\local\programs\python\python311\lib\site-packages (from jupyter_packaging>=0.12.3->keplergl) (0.45.1)
# Requirement already satisfied: async-lru>=1.0.0 in c:\users\tan kai jian\appdata\local\programs\python\python311\lib\site-packages (from jupyterlab>=4.1.6->keplergl) (2.0.5)
# Requirement already satisfied: httpx>=0.25.0 in c:\users\tan kai jian\appdata\local\programs\python\python311\lib\site-packages (from jupyterlab>=4.1.6->keplergl) (0.28.1)
# Requirement already satisfied: jupyter-core in c:\users\tan kai jian\appdata\roaming\python\python311\site-packages (from jupyterlab>=4.1.6->keplergl) (5.7.2)
# Requirement already satisfied: jupyter-lsp>=2.0.0 in c:\users\tan kai jian\appdata\local\programs\python\python311\lib\site-packages (from jupyterlab>=4.1.6->keplergl) (2.2.5)
# Requirement already satisfied: jupyter-server<3,>=2.4.0 in c:\users\tan kai jian\appdata\local\programs\python\python311\lib\site-packages (from jupyterlab>=4.1.6->keplergl) (2.15.0)
# Requirement already satisfied: jupyterlab-server<3,>=2.27.1 in c:\users\tan kai jian\appdata\local\programs\python\python311\lib\site-packages (from jupyterlab>=4.1.6->keplergl) (2.27.3)
# Requirement already satisfied: notebook-shim>=0.2 in c:\users\tan kai jian\appdata\local\programs\python\python311\lib\site-packages (from jupyterlab>=4.1.6->keplergl) (0.2.4)
# Requirement already satisfied: tornado>=6.2.0 in c:\users\tan kai jian\appdata\roaming\python\python311\site-packages (from jupyterlab>=4.1.6->keplergl) (6.4.2)
# Requirement already satisfied: six>=1.5 in c:\users\tan kai jian\appdata\roaming\python\python311\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Requirement already satisfied: anyio in c:\users\tan kai jian\appdata\local\programs\python\python311\lib\site-packages (from httpx>=0.25.0->jupyterlab>=4.1.6->keplergl) (4.9.0)
# Requirement already satisfied: certifi in c:\users\tan kai jian\appdata\local\programs\python\python311\lib\site-packages (from httpx>=0.25.0->jupyterlab>=4.1.6->keplergl) (2025.1.31)
# Requirement already satisfied: httpcore==1.* in c:\users\tan kai jian\appdata\local\programs\python\python311\lib\site-packages (from httpx>=0.25.0->jupyterlab>=4.1.6->keplergl) (1.0.7)
# Requirement already satisfied: idna in c:\users\tan kai jian\appdata\local\programs\python\python311\lib\site-packages (from httpx>=0.25.0->jupyterlab>=4.1.6->keplergl) (3.10)
# Requirement already satisfied: h11<0.15,>=0.13 in c:\users\tan kai jian\appdata\local\programs\python\python311\lib\site-packages (from httpcore==1.*->httpx>=0.25.0->jupyterlab>=4.1.6->keplergl) (0.14.0)
# Requirement already satisfied: debugpy>=1.6.5 in c:\users\tan kai jian\appdata\roaming\python\python311\site-packages (from ipykernel->jupyter>=1.0.0->keplergl) (1.8.14)
# Requirement already satisfied: jupyter-client>=6.1.12 in c:\users\tan kai jian\appdata\roaming\python\python311\site-packages (from ipykernel->jupyter>=1.0.0->keplergl) (8.6.3)
# Requirement already satisfied: matplotlib-inline>=0.1 in c:\users\tan kai jian\appdata\roaming\python\python311\site-packages (from ipykernel->jupyter>=1.0.0->keplergl) (0.1.7)
# Requirement already satisfied: nest-asyncio in c:\users\tan kai jian\appdata\roaming\python\python311\site-packages (from ipykernel->jupyter>=1.0.0->keplergl) (1.6.0)
# Requirement already satisfied: psutil in c:\users\tan kai jian\appdata\roaming\python\python311\site-packages (from ipykernel->jupyter>=1.0.0->keplergl) (7.0.0)
# Requirement already satisfied: pyzmq>=24 in c:\users\tan kai jian\appdata\roaming\python\python311\site-packages (from ipykernel->jupyter>=1.0.0->keplergl) (26.4.0)
# Requirement already satisfied: decorator in c:\users\tan kai jian\appdata\roaming\python\python311\site-packages (from ipython>=6.1.0->ipywidgets>=8.1.5->keplergl) (5.2.1)
# Requirement already satisfied: ipython-pygments-lexers in c:\users\tan kai jian\appdata\roaming\python\python311\site-packages (from ipython>=6.1.0->ipywidgets>=8.1.5->keplergl) (1.1.1)
# Requirement already satisfied: jedi>=0.16 in c:\users\tan kai jian\appdata\roaming\python\python311\site-packages (from ipython>=6.1.0->ipywidgets>=8.1.5->keplergl) (0.19.2)
# Requirement already satisfied: prompt_toolkit<3.1.0,>=3.0.41 in c:\users\tan kai jian\appdata\roaming\python\python311\site-packages (from ipython>=6.1.0->ipywidgets>=8.1.5->keplergl) (3.0.50)
# Requirement already satisfied: pygments>=2.4.0 in c:\users\tan kai jian\appdata\roaming\python\python311\site-packages (from ipython>=6.1.0->ipywidgets>=8.1.5->keplergl) (2.19.1)
# Requirement already satisfied: stack_data in c:\users\tan kai jian\appdata\roaming\python\python311\site-packages (from ipython>=6.1.0->ipywidgets>=8.1.5->keplergl) (0.6.3)
# Requirement already satisfied: platformdirs>=2.5 in c:\users\tan kai jian\appdata\roaming\python\python311\site-packages (from jupyter-core->jupyterlab>=4.1.6->keplergl) (4.3.7)
# Requirement already satisfied: pywin32>=300 in c:\users\tan kai jian\appdata\roaming\python\python311\site-packages (from jupyter-core->jupyterlab>=4.1.6->keplergl) (310)
# Requirement already satisfied: argon2-cffi>=21.1 in c:\users\tan kai jian\appdata\local\programs\python\python311\lib\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab>=4.1.6->keplergl) (23.1.0)
# Requirement already satisfied: jupyter-events>=0.11.0 in c:\users\tan kai jian\appdata\local\programs\python\python311\lib\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab>=4.1.6->keplergl) (0.12.0)
# Requirement already satisfied: jupyter-server-terminals>=0.4.4 in c:\users\tan kai jian\appdata\local\programs\python\python311\lib\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab>=4.1.6->keplergl) (0.5.3)
# Requirement already satisfied: nbformat>=5.3.0 in c:\users\tan kai jian\appdata\local\programs\python\python311\lib\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab>=4.1.6->keplergl) (5.10.4)
# Requirement already satisfied: overrides>=5.0 in c:\users\tan kai jian\appdata\local\programs\python\python311\lib\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab>=4.1.6->keplergl) (7.7.0)
# Requirement already satisfied: prometheus-client>=0.9 in c:\users\tan kai jian\appdata\local\programs\python\python311\lib\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab>=4.1.6->keplergl) (0.21.1)
# Requirement already satisfied: pywinpty>=2.0.1 in c:\users\tan kai jian\appdata\local\programs\python\python311\lib\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab>=4.1.6->keplergl) (2.0.15)
# Requirement already satisfied: send2trash>=1.8.2 in c:\users\tan kai jian\appdata\local\programs\python\python311\lib\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab>=4.1.6->keplergl) (1.8.3)
# Requirement already satisfied: terminado>=0.8.3 in c:\users\tan kai jian\appdata\local\programs\python\python311\lib\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab>=4.1.6->keplergl) (0.18.1)
# Requirement already satisfied: websocket-client>=1.7 in c:\users\tan kai jian\appdata\local\programs\python\python311\lib\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab>=4.1.6->keplergl) (1.8.0)
# Requirement already satisfied: babel>=2.10 in c:\users\tan kai jian\appdata\local\programs\python\python311\lib\site-packages (from jupyterlab-server<3,>=2.27.1->jupyterlab>=4.1.6->keplergl) (2.17.0)
# Requirement already satisfied: json5>=0.9.0 in c:\users\tan kai jian\appdata\local\programs\python\python311\lib\site-packages (from jupyterlab-server<3,>=2.27.1->jupyterlab>=4.1.6->keplergl) (0.12.0)
# Requirement already satisfied: jsonschema>=4.18.0 in c:\users\tan kai jian\appdata\local\programs\python\python311\lib\site-packages (from jupyterlab-server<3,>=2.27.1->jupyterlab>=4.1.6->keplergl) (4.23.0)
# Requirement already satisfied: requests>=2.31 in c:\users\tan kai jian\appdata\local\programs\python\python311\lib\site-packages (from jupyterlab-server<3,>=2.27.1->jupyterlab>=4.1.6->keplergl) (2.32.3)
# Requirement already satisfied: beautifulsoup4 in c:\users\tan kai jian\appdata\local\programs\python\python311\lib\site-packages (from nbconvert->jupyter>=1.0.0->keplergl) (4.13.3)
# Requirement already satisfied: bleach[css]!=5.0.0 in c:\users\tan kai jian\appdata\local\programs\python\python311\lib\site-packages (from nbconvert->jupyter>=1.0.0->keplergl) (6.2.0)
# Requirement already satisfied: defusedxml in c:\users\tan kai jian\appdata\local\programs\python\python311\lib\site-packages (from nbconvert->jupyter>=1.0.0->keplergl) (0.7.1)
# Requirement already satisfied: jupyterlab-pygments in c:\users\tan kai jian\appdata\local\programs\python\python311\lib\site-packages (from nbconvert->jupyter>=1.0.0->keplergl) (0.3.0)
# Requirement already satisfied: mistune<4,>=2.0.3 in c:\users\tan kai jian\appdata\local\programs\python\python311\lib\site-packages (from nbconvert->jupyter>=1.0.0->keplergl) (3.1.3)
# Requirement already satisfied: nbclient>=0.5.0 in c:\users\tan kai jian\appdata\local\programs\python\python311\lib\site-packages (from nbconvert->jupyter>=1.0.0->keplergl) (0.10.2)
# Requirement already satisfied: pandocfilters>=1.4.1 in c:\users\tan kai jian\appdata\local\programs\python\python311\lib\site-packages (from nbconvert->jupyter>=1.0.0->keplergl) (1.5.1)
# Requirement already satisfied: sniffio>=1.1 in c:\users\tan kai jian\appdata\local\programs\python\python311\lib\site-packages (from anyio->httpx>=0.25.0->jupyterlab>=4.1.6->keplergl) (1.3.1)
# Requirement already satisfied: argon2-cffi-bindings in c:\users\tan kai jian\appdata\local\programs\python\python311\lib\site-packages (from argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->jupyterlab>=4.1.6->keplergl) (21.2.0)
# Requirement already satisfied: webencodings in c:\users\tan kai jian\appdata\local\programs\python\python311\lib\site-packages (from bleach[css]!=5.0.0->nbconvert->jupyter>=1.0.0->keplergl) (0.5.1)
# Requirement already satisfied: tinycss2<1.5,>=1.1.0 in c:\users\tan kai jian\appdata\local\programs\python\python311\lib\site-packages (from bleach[css]!=5.0.0->nbconvert->jupyter>=1.0.0->keplergl) (1.4.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in c:\users\tan kai jian\appdata\roaming\python\python311\site-packages (from jedi>=0.16->ipython>=6.1.0->ipywidgets>=8.1.5->keplergl) (0.8.4)
# Requirement already satisfied: attrs>=22.2.0 in c:\users\tan kai jian\appdata\local\programs\python\python311\lib\site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->jupyterlab>=4.1.6->keplergl) (25.3.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in c:\users\tan kai jian\appdata\local\programs\python\python311\lib\site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->jupyterlab>=4.1.6->keplergl) (2024.10.1)
# Requirement already satisfied: referencing>=0.28.4 in c:\users\tan kai jian\appdata\local\programs\python\python311\lib\site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->jupyterlab>=4.1.6->keplergl) (0.36.2)
# Requirement already satisfied: rpds-py>=0.7.1 in c:\users\tan kai jian\appdata\local\programs\python\python311\lib\site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->jupyterlab>=4.1.6->keplergl) (0.24.0)
# Requirement already satisfied: python-json-logger>=2.0.4 in c:\users\tan kai jian\appdata\local\programs\python\python311\lib\site-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab>=4.1.6->keplergl) (3.3.0)
# Requirement already satisfied: pyyaml>=5.3 in c:\users\tan kai jian\appdata\local\programs\python\python311\lib\site-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab>=4.1.6->keplergl) (6.0.2)
# Requirement already satisfied: rfc3339-validator in c:\users\tan kai jian\appdata\local\programs\python\python311\lib\site-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab>=4.1.6->keplergl) (0.1.4)
# Requirement already satisfied: rfc3986-validator>=0.1.1 in c:\users\tan kai jian\appdata\local\programs\python\python311\lib\site-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab>=4.1.6->keplergl) (0.1.1)
# Requirement already satisfied: fastjsonschema>=2.15 in c:\users\tan kai jian\appdata\local\programs\python\python311\lib\site-packages (from nbformat>=5.3.0->jupyter-server<3,>=2.4.0->jupyterlab>=4.1.6->keplergl) (2.21.1)
# Requirement already satisfied: wcwidth in c:\users\tan kai jian\appdata\roaming\python\python311\site-packages (from prompt_toolkit<3.1.0,>=3.0.41->ipython>=6.1.0->ipywidgets>=8.1.5->keplergl) (0.2.13)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\tan kai jian\appdata\local\programs\python\python311\lib\site-packages (from requests>=2.31->jupyterlab-server<3,>=2.27.1->jupyterlab>=4.1.6->keplergl) (3.4.1)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\tan kai jian\appdata\local\programs\python\python311\lib\site-packages (from requests>=2.31->jupyterlab-server<3,>=2.27.1->jupyterlab>=4.1.6->keplergl) (2.4.0)
# Requirement already satisfied: soupsieve>1.2 in c:\users\tan kai jian\appdata\local\programs\python\python311\lib\site-packages (from beautifulsoup4->nbconvert->jupyter>=1.0.0->keplergl) (2.6)
# Requirement already satisfied: executing>=1.2.0 in c:\users\tan kai jian\appdata\roaming\python\python311\site-packages (from stack_data->ipython>=6.1.0->ipywidgets>=8.1.5->keplergl) (2.2.0)
# Requirement already satisfied: asttokens>=2.1.0 in c:\users\tan kai jian\appdata\roaming\python\python311\site-packages (from stack_data->ipython>=6.1.0->ipywidgets>=8.1.5->keplergl) (3.0.0)
# Requirement already satisfied: pure-eval in c:\users\tan kai jian\appdata\roaming\python\python311\site-packages (from stack_data->ipython>=6.1.0->ipywidgets>=8.1.5->keplergl) (0.2.3)
# Requirement already satisfied: fqdn in c:\users\tan kai jian\appdata\local\programs\python\python311\lib\site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->jupyterlab>=4.1.6->keplergl) (1.5.1)
# Requirement already satisfied: isoduration in c:\users\tan kai jian\appdata\local\programs\python\python311\lib\site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->jupyterlab>=4.1.6->keplergl) (20.11.0)
# Requirement already satisfied: jsonpointer>1.13 in c:\users\tan kai jian\appdata\local\programs\python\python311\lib\site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->jupyterlab>=4.1.6->keplergl) (3.0.0)
# Requirement already satisfied: uri-template in c:\users\tan kai jian\appdata\local\programs\python\python311\lib\site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->jupyterlab>=4.1.6->keplergl) (1.3.0)
# Requirement already satisfied: webcolors>=24.6.0 in c:\users\tan kai jian\appdata\local\programs\python\python311\lib\site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->jupyterlab>=4.1.6->keplergl) (24.11.1)
# Requirement already satisfied: cffi>=1.0.1 in c:\users\tan kai jian\appdata\local\programs\python\python311\lib\site-packages (from argon2-cffi-bindings->argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->jupyterlab>=4.1.6->keplergl) (1.17.1)
# Requirement already satisfied: pycparser in c:\users\tan kai jian\appdata\local\programs\python\python311\lib\site-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->jupyterlab>=4.1.6->keplergl) (2.22)
# Requirement already satisfied: arrow>=0.15.0 in c:\users\tan kai jian\appdata\local\programs\python\python311\lib\site-packages (from isoduration->jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->jupyterlab>=4.1.6->keplergl) (1.3.0)
# Requirement already satisfied: types-python-dateutil>=2.8.10 in c:\users\tan kai jian\appdata\local\programs\python\python311\lib\site-packages (from arrow>=0.15.0->isoduration->jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->jupyterlab>=4.1.6->keplergl) (2.9.0.20241206)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip available: 22.3 -> 25.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
from flask import Flask, Response, render_template_string
import threading
import pandas as pd
from sqlalchemy import create_engine
from keplergl import KeplerGl
import matplotlib.pyplot as plt
import io
import base64

# === Database config ===
DB_USER = "testing1_415q_user"
DB_PASSWORD = "syezjh72qciEKZUCBIcR4LF6YkiH7aXK"
DB_HOST = "dpg-cvr1u8ngi27c738j3acg-a.singapore-postgres.render.com"
DB_PORT = "5432"
DB_NAME = "testing1_415q"

# === Connect to DB ===
engine = create_engine(f"postgresql+psycopg2://{DB_USER}:{DB_PASSWORD}@{DB_HOST}:{DB_PORT}/{DB_NAME}")
query = "SELECT name, amenity, latitude, longitude FROM health_facilities;"

# === Flask app ===
app = Flask(__name__)

# === Map config ===
config = {
    'version': 'v1',
    'config': {
        'mapState': {
            'latitude': 3.944035,
            'longitude': 102.638624,
            'zoom': 4.32
        }
    }
}

# === Function to create donut chart ===
def create_donut_chart():
    df = pd.read_sql(query, engine)
    amenities_count = df['amenity'].value_counts()

    # Create donut chart
    fig, ax = plt.subplots(figsize=(5, 5))
    ax.pie(amenities_count, labels=amenities_count.index, autopct='%1.1f%%', startangle=90, wedgeprops={'width': 0.4})
    ax.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.

    # Save it to a BytesIO object and convert to base64
    img_bytes = io.BytesIO()
    plt.savefig(img_bytes, format='png')
    img_bytes.seek(0)
    img_base64 = base64.b64encode(img_bytes.read()).decode('utf-8')

    return img_base64

# === Main route with buttons ===
@app.route('/')
def index():
    # Generate the donut chart as a base64 string
    chart_image = create_donut_chart()

    # Embed the base64 chart image into the HTML template
    html = f"""
<!DOCTYPE html>
<html>
<head>
    <title>Health Facilities Map</title>
    <style>
        * {{
            box-sizing: border-box;
        }}
        body {{
            margin: 0;
            padding: 0;
            font-family: sans-serif;
            text-align: center;
            background-color: #f4f4f4;
            height: 100vh;
            overflow-x: hidden; /* Prevent horizontal scrolling */
        }}
        .container {{
            display: flex;
            justify-content: space-between;
            align-items: flex-start;
            width: 100%;
            padding: 10px;
            flex-direction: column; /* Arrange the elements vertically */
        }}
        iframe {{
            width: 70vw; /* Adjust the width to 70% of the viewport */
            height: 70vh; /* Height is 60% of the viewport height */
            border: none;
        }}
        .button-container {{
            display: flex;
            justify-content: center;
            margin-top: 20px;
        }}
        .chart-container {{
            width: 70vw; 
            height: 80vh; 
            padding: 20px;
            background-color: #fff;
            border-radius: 8px;
            box-shadow: 0 0 10px rgba(0, 0, 0, 0.1);
            overflow-y: auto;
            margin-top: 20px;
        }}
        .btn {{
            padding: 10px 20px;
            font-size: 16px;
            cursor: pointer;
            background-color: #007BFF;
            color: white;
            border: 2px solid #0056b3;
            border-radius: 5px;
            margin: 0 10px;
        }}
        .btn:hover {{
            background-color: #0056b3;
        }}
        #kepler-gl__map {{
            width: 100% !important;
            height: 100vh !important;
        }}
    </style>
</head>
<body>
    <div class="container">
        <iframe id="mapFrame" src="/map"></iframe>
        
        <div class="button-container">
            <button class="btn" onclick="refreshMap()">Refresh Map</button>
            <button class="btn" onclick="showClinicsOnly()">Show Clinics Only</button>
        </div>
        
        <div class="chart-container">
            <h3>Amenity Distribution</h3>
            <img src="data:image/png;base64,{chart_image}" alt="Donut Chart">
        </div>
    </div>

    <!-- The script block with functions -->
    <script>
        function refreshMap() {{
            document.getElementById("mapFrame").src = "/map?" + new Date().getTime();
        }}

        function showClinicsOnly() {{
            document.getElementById("mapFrame").src = "/map/clinic?" + new Date().getTime();
        }}
    </script>
</body>
</html>
"""
    return render_template_string(html)


# === Default full map ===
@app.route('/map')
def map_all():
    df = pd.read_sql(query, engine)
    map_ = KeplerGl(height=600)
    map_.add_data(data=df, name='All Health Facilities')
    map_.config = config
    return Response(map_._repr_html_(), mimetype='text/html')

# === Filtered clinic-only map ===
@app.route('/map/clinic')
def map_clinic():
    df = pd.read_sql(query, engine)
    clinic_df = df[df['amenity'].str.lower() == 'clinic']  # Filter for clinics only
    map_ = KeplerGl(height=600)
    map_.add_data(data=clinic_df, name='Clinics Only')
    map_.config = config
    return Response(map_._repr_html_(), mimetype='text/html')

# === Run Flask ===
def run_flask():
    app.run(debug=True, port=5006, use_reloader=False)

threading.Thread(target=run_flask).start()
# Out:
#  * Serving Flask app '__main__'
#  * Debug mode: on
# WARNING: This is a development server. Do not use it in a production deployment. Use a production WSGI server instead.
#  * Running on http://127.0.0.1:5006
# Press CTRL+C to quit
# 127.0.0.1 - - [14/Apr/2025 15:25:55] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Apr/2025 15:25:55] "GET /map HTTP/1.1" 200 -
# User Guide: https://docs.kepler.gl/docs/keplergl-jupyter

# %%
# %pip install plotly
# Out:
# Requirement already satisfied: plotly in c:\users\tan kai jian\appdata\local\programs\python\python311\lib\site-packages (6.0.1)
# Requirement already satisfied: narwhals>=1.15.1 in c:\users\tan kai jian\appdata\local\programs\python\python311\lib\site-packages (from plotly) (1.34.1)
# Requirement already satisfied: packaging in c:\users\tan kai jian\appdata\roaming\python\python311\site-packages (from plotly) (24.2)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip available: 22.3 -> 25.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
