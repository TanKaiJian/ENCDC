# %% [markdown]
# Connect with databse postgres online

# %%
# %pip install flask pandas sqlalchemy psycopg2 keplergl matplotlib
# Out:
# Collecting flask
#   Using cached flask-3.1.0-py3-none-any.whl (102 kB)
# Collecting pandas
#   Using cached pandas-2.2.3-cp311-cp311-win_amd64.whl (11.6 MB)
# Collecting sqlalchemy
#   Using cached sqlalchemy-2.0.40-cp311-cp311-win_amd64.whl (2.1 MB)
# Collecting psycopg2
#   Using cached psycopg2-2.9.10-cp311-cp311-win_amd64.whl (1.2 MB)
# Collecting keplergl
#   Using cached keplergl-0.3.7-py2.py3-none-any.whl
# Collecting matplotlib
#   Using cached matplotlib-3.10.1-cp311-cp311-win_amd64.whl (8.1 MB)
# Collecting Werkzeug>=3.1
#   Using cached werkzeug-3.1.3-py3-none-any.whl (224 kB)
# Collecting Jinja2>=3.1.2
#   Using cached jinja2-3.1.6-py3-none-any.whl (134 kB)
# Collecting itsdangerous>=2.2
#   Using cached itsdangerous-2.2.0-py3-none-any.whl (16 kB)
# Collecting click>=8.1.3
#   Using cached click-8.1.8-py3-none-any.whl (98 kB)
# Collecting blinker>=1.9
#   Using cached blinker-1.9.0-py3-none-any.whl (8.5 kB)
# Collecting numpy>=1.23.2
#   Using cached numpy-2.2.4-cp311-cp311-win_amd64.whl (12.9 MB)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\tan kai jian\appdata\roaming\python\python311\site-packages (from pandas) (2.9.0.post0)
# Collecting pytz>=2020.1
#   Using cached pytz-2025.2-py2.py3-none-any.whl (509 kB)
# Collecting tzdata>=2022.7
#   Using cached tzdata-2025.2-py2.py3-none-any.whl (347 kB)
# Collecting greenlet>=1
#   Using cached greenlet-3.1.1-cp311-cp311-win_amd64.whl (298 kB)
# Requirement already satisfied: typing-extensions>=4.6.0 in c:\users\tan kai jian\appdata\roaming\python\python311\site-packages (from sqlalchemy) (4.13.2)
# Collecting ipywidgets>=8.1.5
#   Downloading ipywidgets-8.1.6-py3-none-any.whl (139 kB)
#      -------------------------------------- 139.8/139.8 kB 2.8 MB/s eta 0:00:00
# Collecting traittypes>=0.2.1
#   Using cached traittypes-0.2.1-py2.py3-none-any.whl (8.6 kB)
# Requirement already satisfied: traitlets>=4.3.2 in c:\users\tan kai jian\appdata\roaming\python\python311\site-packages (from keplergl) (5.14.3)
# Collecting geopandas>=0.14.3
#   Using cached geopandas-1.0.1-py3-none-any.whl (323 kB)
# Collecting Shapely>=1.6.4.post2
#   Using cached shapely-2.1.0-cp311-cp311-win_amd64.whl (1.7 MB)
# Collecting jupyter_packaging>=0.12.3
#   Using cached jupyter_packaging-0.12.3-py3-none-any.whl (15 kB)
# Collecting jupyter>=1.0.0
#   Using cached jupyter-1.1.1-py2.py3-none-any.whl (2.7 kB)
# Collecting jupyterlab>=4.1.6
#   Using cached jupyterlab-4.4.0-py3-none-any.whl (12.3 MB)
# Collecting notebook>=6.0.1
#   Using cached notebook-7.4.0-py3-none-any.whl (14.3 MB)
# Collecting pyarrow>=16.0.0
#   Using cached pyarrow-19.0.1-cp311-cp311-win_amd64.whl (25.3 MB)
# Collecting geoarrow-pyarrow>=0.1.2
#   Using cached geoarrow_pyarrow-0.1.2-py3-none-any.whl (26 kB)
# Collecting geoarrow-pandas>=0.1.1
#   Using cached geoarrow_pandas-0.1.1-py3-none-any.whl (6.2 kB)
# Collecting contourpy>=1.0.1
#   Using cached contourpy-1.3.1-cp311-cp311-win_amd64.whl (219 kB)
# Collecting cycler>=0.10
#   Using cached cycler-0.12.1-py3-none-any.whl (8.3 kB)
# Collecting fonttools>=4.22.0
#   Using cached fonttools-4.57.0-cp311-cp311-win_amd64.whl (2.2 MB)
# Collecting kiwisolver>=1.3.1
#   Using cached kiwisolver-1.4.8-cp311-cp311-win_amd64.whl (71 kB)
# Requirement already satisfied: packaging>=20.0 in c:\users\tan kai jian\appdata\roaming\python\python311\site-packages (from matplotlib) (24.2)
# Collecting pillow>=8
#   Using cached pillow-11.1.0-cp311-cp311-win_amd64.whl (2.6 MB)
# Collecting pyparsing>=2.3.1
#   Using cached pyparsing-3.2.3-py3-none-any.whl (111 kB)
# Requirement already satisfied: colorama in c:\users\tan kai jian\appdata\roaming\python\python311\site-packages (from click>=8.1.3->flask) (0.4.6)
# Collecting geoarrow-c
#   Using cached geoarrow_c-0.1.2-cp311-cp311-win_amd64.whl (432 kB)
# Collecting pyarrow-hotfix
#   Using cached pyarrow_hotfix-0.6-py3-none-any.whl (7.9 kB)
# Collecting pyogrio>=0.7.2
#   Using cached pyogrio-0.10.0-cp311-cp311-win_amd64.whl (16.2 MB)
# Collecting pyproj>=3.3.0
#   Using cached pyproj-3.7.1-cp311-cp311-win_amd64.whl (6.3 MB)
# Requirement already satisfied: comm>=0.1.3 in c:\users\tan kai jian\appdata\roaming\python\python311\site-packages (from ipywidgets>=8.1.5->keplergl) (0.2.2)
# Requirement already satisfied: ipython>=6.1.0 in c:\users\tan kai jian\appdata\roaming\python\python311\site-packages (from ipywidgets>=8.1.5->keplergl) (9.1.0)
# Collecting widgetsnbextension~=4.0.14
#   Using cached widgetsnbextension-4.0.14-py3-none-any.whl (2.2 MB)
# Collecting jupyterlab_widgets~=3.0.14
#   Downloading jupyterlab_widgets-3.0.14-py3-none-any.whl (213 kB)
#      -------------------------------------- 214.0/214.0 kB 6.6 MB/s eta 0:00:00
# Collecting MarkupSafe>=2.0
#   Using cached MarkupSafe-3.0.2-cp311-cp311-win_amd64.whl (15 kB)
# Collecting jupyter-console
#   Using cached jupyter_console-6.6.3-py3-none-any.whl (24 kB)
# Collecting nbconvert
#   Using cached nbconvert-7.16.6-py3-none-any.whl (258 kB)
# Requirement already satisfied: ipykernel in c:\users\tan kai jian\appdata\roaming\python\python311\site-packages (from jupyter>=1.0.0->keplergl) (6.29.5)
# Collecting deprecation
#   Using cached deprecation-2.1.0-py2.py3-none-any.whl (11 kB)
# Requirement already satisfied: setuptools>=60.2.0 in c:\users\tan kai jian\appdata\local\programs\python\python311\lib\site-packages (from jupyter_packaging>=0.12.3->keplergl) (65.5.0)
# Collecting tomlkit
#   Using cached tomlkit-0.13.2-py3-none-any.whl (37 kB)
# Collecting wheel
#   Using cached wheel-0.45.1-py3-none-any.whl (72 kB)
# Collecting async-lru>=1.0.0
#   Using cached async_lru-2.0.5-py3-none-any.whl (6.1 kB)
# Collecting httpx>=0.25.0
#   Using cached httpx-0.28.1-py3-none-any.whl (73 kB)
# Requirement already satisfied: jupyter-core in c:\users\tan kai jian\appdata\roaming\python\python311\site-packages (from jupyterlab>=4.1.6->keplergl) (5.7.2)
# Collecting jupyter-lsp>=2.0.0
#   Using cached jupyter_lsp-2.2.5-py3-none-any.whl (69 kB)
# Collecting jupyter-server<3,>=2.4.0
#   Using cached jupyter_server-2.15.0-py3-none-any.whl (385 kB)
# Collecting jupyterlab-server<3,>=2.27.1
#   Using cached jupyterlab_server-2.27.3-py3-none-any.whl (59 kB)
# Collecting notebook-shim>=0.2
#   Using cached notebook_shim-0.2.4-py3-none-any.whl (13 kB)
# Requirement already satisfied: tornado>=6.2.0 in c:\users\tan kai jian\appdata\roaming\python\python311\site-packages (from jupyterlab>=4.1.6->keplergl) (6.4.2)
# Requirement already satisfied: six>=1.5 in c:\users\tan kai jian\appdata\roaming\python\python311\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Collecting anyio
#   Using cached anyio-4.9.0-py3-none-any.whl (100 kB)
# Collecting certifi
#   Using cached certifi-2025.1.31-py3-none-any.whl (166 kB)
# Collecting httpcore==1.*
#   Using cached httpcore-1.0.7-py3-none-any.whl (78 kB)
# Collecting idna
#   Using cached idna-3.10-py3-none-any.whl (70 kB)
# Collecting h11<0.15,>=0.13
#   Using cached h11-0.14.0-py3-none-any.whl (58 kB)
# Requirement already satisfied: debugpy>=1.6.5 in c:\users\tan kai jian\appdata\roaming\python\python311\site-packages (from ipykernel->jupyter>=1.0.0->keplergl) (1.8.14)
# Requirement already satisfied: jupyter-client>=6.1.12 in c:\users\tan kai jian\appdata\roaming\python\python311\site-packages (from ipykernel->jupyter>=1.0.0->keplergl) (8.6.3)
# Requirement already satisfied: matplotlib-inline>=0.1 in c:\users\tan kai jian\appdata\roaming\python\python311\site-packages (from ipykernel->jupyter>=1.0.0->keplergl) (0.1.7)
# Requirement already satisfied: nest-asyncio in c:\users\tan kai jian\appdata\roaming\python\python311\site-packages (from ipykernel->jupyter>=1.0.0->keplergl) (1.6.0)
# Requirement already satisfied: psutil in c:\users\tan kai jian\appdata\roaming\python\python311\site-packages (from ipykernel->jupyter>=1.0.0->keplergl) (7.0.0)
# Requirement already satisfied: pyzmq>=24 in c:\users\tan kai jian\appdata\roaming\python\python311\site-packages (from ipykernel->jupyter>=1.0.0->keplergl) (26.4.0)
# Requirement already satisfied: decorator in c:\users\tan kai jian\appdata\roaming\python\python311\site-packages (from ipython>=6.1.0->ipywidgets>=8.1.5->keplergl) (5.2.1)
# Requirement already satisfied: ipython-pygments-lexers in c:\users\tan kai jian\appdata\roaming\python\python311\site-packages (from ipython>=6.1.0->ipywidgets>=8.1.5->keplergl) (1.1.1)
# Requirement already satisfied: jedi>=0.16 in c:\users\tan kai jian\appdata\roaming\python\python311\site-packages (from ipython>=6.1.0->ipywidgets>=8.1.5->keplergl) (0.19.2)
# Requirement already satisfied: prompt_toolkit<3.1.0,>=3.0.41 in c:\users\tan kai jian\appdata\roaming\python\python311\site-packages (from ipython>=6.1.0->ipywidgets>=8.1.5->keplergl) (3.0.50)
# Requirement already satisfied: pygments>=2.4.0 in c:\users\tan kai jian\appdata\roaming\python\python311\site-packages (from ipython>=6.1.0->ipywidgets>=8.1.5->keplergl) (2.19.1)
# Requirement already satisfied: stack_data in c:\users\tan kai jian\appdata\roaming\python\python311\site-packages (from ipython>=6.1.0->ipywidgets>=8.1.5->keplergl) (0.6.3)
# Requirement already satisfied: platformdirs>=2.5 in c:\users\tan kai jian\appdata\roaming\python\python311\site-packages (from jupyter-core->jupyterlab>=4.1.6->keplergl) (4.3.7)
# Requirement already satisfied: pywin32>=300 in c:\users\tan kai jian\appdata\roaming\python\python311\site-packages (from jupyter-core->jupyterlab>=4.1.6->keplergl) (310)
# Collecting argon2-cffi>=21.1
#   Using cached argon2_cffi-23.1.0-py3-none-any.whl (15 kB)
# Collecting jupyter-events>=0.11.0
#   Using cached jupyter_events-0.12.0-py3-none-any.whl (19 kB)
# Collecting jupyter-server-terminals>=0.4.4
#   Using cached jupyter_server_terminals-0.5.3-py3-none-any.whl (13 kB)
# Collecting nbformat>=5.3.0
#   Using cached nbformat-5.10.4-py3-none-any.whl (78 kB)
# Collecting overrides>=5.0
#   Using cached overrides-7.7.0-py3-none-any.whl (17 kB)
# Collecting prometheus-client>=0.9
#   Using cached prometheus_client-0.21.1-py3-none-any.whl (54 kB)
# Collecting pywinpty>=2.0.1
#   Using cached pywinpty-2.0.15-cp311-cp311-win_amd64.whl (1.4 MB)
# Collecting send2trash>=1.8.2
#   Using cached Send2Trash-1.8.3-py3-none-any.whl (18 kB)
# Collecting terminado>=0.8.3
#   Using cached terminado-0.18.1-py3-none-any.whl (14 kB)
# Collecting websocket-client>=1.7
#   Using cached websocket_client-1.8.0-py3-none-any.whl (58 kB)
# Collecting babel>=2.10
#   Using cached babel-2.17.0-py3-none-any.whl (10.2 MB)
# Collecting json5>=0.9.0
#   Using cached json5-0.12.0-py3-none-any.whl (36 kB)
# Collecting jsonschema>=4.18.0
#   Using cached jsonschema-4.23.0-py3-none-any.whl (88 kB)
# Collecting requests>=2.31
#   Using cached requests-2.32.3-py3-none-any.whl (64 kB)
# Collecting beautifulsoup4
#   Using cached beautifulsoup4-4.13.3-py3-none-any.whl (186 kB)
# Collecting bleach[css]!=5.0.0
#   Using cached bleach-6.2.0-py3-none-any.whl (163 kB)
# Collecting defusedxml
#   Using cached defusedxml-0.7.1-py2.py3-none-any.whl (25 kB)
# Collecting jupyterlab-pygments
#   Using cached jupyterlab_pygments-0.3.0-py3-none-any.whl (15 kB)
# Collecting mistune<4,>=2.0.3
#   Using cached mistune-3.1.3-py3-none-any.whl (53 kB)
# Collecting nbclient>=0.5.0
#   Using cached nbclient-0.10.2-py3-none-any.whl (25 kB)
# Collecting pandocfilters>=1.4.1
#   Using cached pandocfilters-1.5.1-py2.py3-none-any.whl (8.7 kB)
# Collecting sniffio>=1.1
#   Using cached sniffio-1.3.1-py3-none-any.whl (10 kB)
# Collecting argon2-cffi-bindings
#   Using cached argon2_cffi_bindings-21.2.0-cp36-abi3-win_amd64.whl (30 kB)
# Collecting webencodings
#   Using cached webencodings-0.5.1-py2.py3-none-any.whl (11 kB)
# Collecting tinycss2<1.5,>=1.1.0
#   Using cached tinycss2-1.4.0-py3-none-any.whl (26 kB)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in c:\users\tan kai jian\appdata\roaming\python\python311\site-packages (from jedi>=0.16->ipython>=6.1.0->ipywidgets>=8.1.5->keplergl) (0.8.4)
# Collecting attrs>=22.2.0
#   Using cached attrs-25.3.0-py3-none-any.whl (63 kB)
# Collecting jsonschema-specifications>=2023.03.6
#   Using cached jsonschema_specifications-2024.10.1-py3-none-any.whl (18 kB)
# Collecting referencing>=0.28.4
#   Using cached referencing-0.36.2-py3-none-any.whl (26 kB)
# Collecting rpds-py>=0.7.1
#   Using cached rpds_py-0.24.0-cp311-cp311-win_amd64.whl (234 kB)
# Collecting python-json-logger>=2.0.4
#   Using cached python_json_logger-3.3.0-py3-none-any.whl (15 kB)
# Collecting pyyaml>=5.3
#   Using cached PyYAML-6.0.2-cp311-cp311-win_amd64.whl (161 kB)
# Collecting rfc3339-validator
#   Using cached rfc3339_validator-0.1.4-py2.py3-none-any.whl (3.5 kB)
# Collecting rfc3986-validator>=0.1.1
#   Using cached rfc3986_validator-0.1.1-py2.py3-none-any.whl (4.2 kB)
# Collecting fastjsonschema>=2.15
#   Using cached fastjsonschema-2.21.1-py3-none-any.whl (23 kB)
# Requirement already satisfied: wcwidth in c:\users\tan kai jian\appdata\roaming\python\python311\site-packages (from prompt_toolkit<3.1.0,>=3.0.41->ipython>=6.1.0->ipywidgets>=8.1.5->keplergl) (0.2.13)
# Collecting charset-normalizer<4,>=2
#   Using cached charset_normalizer-3.4.1-cp311-cp311-win_amd64.whl (102 kB)
# Collecting urllib3<3,>=1.21.1
#   Using cached urllib3-2.4.0-py3-none-any.whl (128 kB)
# Collecting soupsieve>1.2
#   Using cached soupsieve-2.6-py3-none-any.whl (36 kB)
# Requirement already satisfied: executing>=1.2.0 in c:\users\tan kai jian\appdata\roaming\python\python311\site-packages (from stack_data->ipython>=6.1.0->ipywidgets>=8.1.5->keplergl) (2.2.0)
# Requirement already satisfied: asttokens>=2.1.0 in c:\users\tan kai jian\appdata\roaming\python\python311\site-packages (from stack_data->ipython>=6.1.0->ipywidgets>=8.1.5->keplergl) (3.0.0)
# Requirement already satisfied: pure-eval in c:\users\tan kai jian\appdata\roaming\python\python311\site-packages (from stack_data->ipython>=6.1.0->ipywidgets>=8.1.5->keplergl) (0.2.3)
# Collecting fqdn
#   Using cached fqdn-1.5.1-py3-none-any.whl (9.1 kB)
# Collecting isoduration
#   Using cached isoduration-20.11.0-py3-none-any.whl (11 kB)
# Collecting jsonpointer>1.13
#   Using cached jsonpointer-3.0.0-py2.py3-none-any.whl (7.6 kB)
# Collecting uri-template
#   Using cached uri_template-1.3.0-py3-none-any.whl (11 kB)
# Collecting webcolors>=24.6.0
#   Using cached webcolors-24.11.1-py3-none-any.whl (14 kB)
# Collecting cffi>=1.0.1
#   Using cached cffi-1.17.1-cp311-cp311-win_amd64.whl (181 kB)
# Collecting pycparser
#   Using cached pycparser-2.22-py3-none-any.whl (117 kB)
# Collecting arrow>=0.15.0
#   Using cached arrow-1.3.0-py3-none-any.whl (66 kB)
# Collecting types-python-dateutil>=2.8.10
#   Using cached types_python_dateutil-2.9.0.20241206-py3-none-any.whl (14 kB)
# Installing collected packages: webencodings, pytz, fastjsonschema, widgetsnbextension, wheel, websocket-client, webcolors, urllib3, uri-template, tzdata, types-python-dateutil, traittypes, tomlkit, tinycss2, soupsieve, sniffio, send2trash, rpds-py, rfc3986-validator, rfc3339-validator, pyyaml, pywinpty, python-json-logger, pyparsing, pycparser, pyarrow-hotfix, pyarrow, psycopg2, prometheus-client, pillow, pandocfilters, overrides, numpy, mistune, MarkupSafe, kiwisolver, jupyterlab_widgets, jupyterlab-pygments, jsonpointer, json5, itsdangerous, idna, h11, greenlet, geoarrow-c, fqdn, fonttools, deprecation, defusedxml, cycler, click, charset-normalizer, certifi, blinker, bleach, babel, attrs, async-lru, Werkzeug, terminado, sqlalchemy, Shapely, requests, referencing, pyproj, pyogrio, pandas, jupyter_packaging, Jinja2, httpcore, geoarrow-pyarrow, contourpy, cffi, beautifulsoup4, arrow, anyio, matplotlib, jupyter-server-terminals, jsonschema-specifications, isoduration, ipywidgets, httpx, geopandas, geoarrow-pandas, flask, argon2-cffi-bindings, jupyter-console, jsonschema, argon2-cffi, nbformat, nbclient, jupyter-events, nbconvert, jupyter-server, notebook-shim, jupyterlab-server, jupyter-lsp, jupyterlab, notebook, jupyter, keplergl
# Successfully installed Jinja2-3.1.6 MarkupSafe-3.0.2 Shapely-2.1.0 Werkzeug-3.1.3 anyio-4.9.0 argon2-cffi-23.1.0 argon2-cffi-bindings-21.2.0 arrow-1.3.0 async-lru-2.0.5 attrs-25.3.0 babel-2.17.0 beautifulsoup4-4.13.3 bleach-6.2.0 blinker-1.9.0 certifi-2025.1.31 cffi-1.17.1 charset-normalizer-3.4.1 click-8.1.8 contourpy-1.3.1 cycler-0.12.1 defusedxml-0.7.1 deprecation-2.1.0 fastjsonschema-2.21.1 flask-3.1.0 fonttools-4.57.0 fqdn-1.5.1 geoarrow-c-0.1.2 geoarrow-pandas-0.1.1 geoarrow-pyarrow-0.1.2 geopandas-1.0.1 greenlet-3.1.1 h11-0.14.0 httpcore-1.0.7 httpx-0.28.1 idna-3.10 ipywidgets-8.1.6 isoduration-20.11.0 itsdangerous-2.2.0 json5-0.12.0 jsonpointer-3.0.0 jsonschema-4.23.0 jsonschema-specifications-2024.10.1 jupyter-1.1.1 jupyter-console-6.6.3 jupyter-events-0.12.0 jupyter-lsp-2.2.5 jupyter-server-2.15.0 jupyter-server-terminals-0.5.3 jupyter_packaging-0.12.3 jupyterlab-4.4.0 jupyterlab-pygments-0.3.0 jupyterlab-server-2.27.3 jupyterlab_widgets-3.0.14 keplergl-0.3.7 kiwisolver-1.4.8 matplotlib-3.10.1 mistune-3.1.3 nbclient-0.10.2 nbconvert-7.16.6 nbformat-5.10.4 notebook-7.4.0 notebook-shim-0.2.4 numpy-2.2.4 overrides-7.7.0 pandas-2.2.3 pandocfilters-1.5.1 pillow-11.1.0 prometheus-client-0.21.1 psycopg2-2.9.10 pyarrow-19.0.1 pyarrow-hotfix-0.6 pycparser-2.22 pyogrio-0.10.0 pyparsing-3.2.3 pyproj-3.7.1 python-json-logger-3.3.0 pytz-2025.2 pywinpty-2.0.15 pyyaml-6.0.2 referencing-0.36.2 requests-2.32.3 rfc3339-validator-0.1.4 rfc3986-validator-0.1.1 rpds-py-0.24.0 send2trash-1.8.3 sniffio-1.3.1 soupsieve-2.6 sqlalchemy-2.0.40 terminado-0.18.1 tinycss2-1.4.0 tomlkit-0.13.2 traittypes-0.2.1 types-python-dateutil-2.9.0.20241206 tzdata-2025.2 uri-template-1.3.0 urllib3-2.4.0 webcolors-24.11.1 webencodings-0.5.1 websocket-client-1.8.0 wheel-0.45.1 widgetsnbextension-4.0.14
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip available: 22.3 -> 25.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
from flask import Flask, Response, render_template_string
import threading
import pandas as pd
from sqlalchemy import create_engine
from keplergl import KeplerGl
import matplotlib.pyplot as plt
import io
import base64

# === Database config ===
DB_USER = "testing1_415q_user"
DB_PASSWORD = "syezjh72qciEKZUCBIcR4LF6YkiH7aXK"
DB_HOST = "dpg-cvr1u8ngi27c738j3acg-a.singapore-postgres.render.com"
DB_PORT = "5432"
DB_NAME = "testing1_415q"

# === Connect to DB ===
engine = create_engine(f"postgresql+psycopg2://{DB_USER}:{DB_PASSWORD}@{DB_HOST}:{DB_PORT}/{DB_NAME}")
query = "SELECT name, amenity, latitude, longitude FROM health_facilities;"

# === Flask app ===
app = Flask(__name__)

# === Map config ===
config = {
    'version': 'v1',
    'config': {
        'mapState': {
            'latitude': 3.944035,
            'longitude': 102.638624,
            'zoom': 4.32
        }
    }
}

# === Function to create donut chart ===
def create_donut_chart():
    df = pd.read_sql(query, engine)
    amenities_count = df['amenity'].value_counts()

    # Create donut chart
    fig, ax = plt.subplots(figsize=(5, 5))
    ax.pie(amenities_count, labels=amenities_count.index, autopct='%1.1f%%', startangle=90, wedgeprops={'width': 0.4})
    ax.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.

    # Save it to a BytesIO object and convert to base64
    img_bytes = io.BytesIO()
    plt.savefig(img_bytes, format='png')
    img_bytes.seek(0)
    img_base64 = base64.b64encode(img_bytes.read()).decode('utf-8')

    return img_base64

# === Main route with buttons ===
@app.route('/')
def index():
    # Generate the donut chart as a base64 string
    chart_image = create_donut_chart()

    # Embed the base64 chart image into the HTML template
    html = f"""
<!DOCTYPE html>
<html>
<head>
    <title>Health Facilities Map</title>
    <style>
        * {{
            box-sizing: border-box;
        }}
        body {{
            margin: 0;
            padding: 0;
            font-family: sans-serif;
            text-align: center;
            background-color: #f4f4f4;
            height: 100vh;
            overflow-x: hidden; /* Prevent horizontal scrolling */
        }}
        .container {{
            display: flex;
            justify-content: space-between;
            align-items: flex-start;
            width: 100%;
            padding: 10px;
            flex-direction: column; /* Arrange the elements vertically */
        }}
        iframe {{
            width: 70vw; /* Adjust the width to 70% of the viewport */
            height: 70vh; /* Height is 60% of the viewport height */
            border: none;
        }}
        .button-container {{
            display: flex;
            justify-content: center;
            margin-top: 20px;
        }}
        .chart-container {{
            width: 70vw; 
            height: 80vh; 
            padding: 20px;
            background-color: #fff;
            border-radius: 8px;
            box-shadow: 0 0 10px rgba(0, 0, 0, 0.1);
            overflow-y: auto;
            margin-top: 20px;
        }}
        .btn {{
            padding: 10px 20px;
            font-size: 16px;
            cursor: pointer;
            background-color: #007BFF;
            color: white;
            border: 2px solid #0056b3;
            border-radius: 5px;
            margin: 0 10px;
        }}
        .btn:hover {{
            background-color: #0056b3;
        }}
        #kepler-gl__map {{
            width: 100% !important;
            height: 100vh !important;
        }}
    </style>
</head>
<body>
    <div class="container">
        <iframe id="mapFrame" src="/map"></iframe>
        
        <div class="button-container">
            <button class="btn" onclick="refreshMap()">Refresh Map</button>
            <button class="btn" onclick="showClinicsOnly()">Show Clinics Only</button>
        </div>
        
        <div class="chart-container">
            <h3>Amenity Distribution</h3>
            <img src="data:image/png;base64,{chart_image}" alt="Donut Chart">
        </div>
    </div>

    <!-- The script block with functions -->
    <script>
        function refreshMap() {{
            document.getElementById("mapFrame").src = "/map?" + new Date().getTime();
        }}

        function showClinicsOnly() {{
            document.getElementById("mapFrame").src = "/map/clinic?" + new Date().getTime();
        }}
    </script>
</body>
</html>
"""
    return render_template_string(html)


# === Default full map ===
@app.route('/map')
def map_all():
    df = pd.read_sql(query, engine)
    map_ = KeplerGl(height=600)
    map_.add_data(data=df, name='All Health Facilities')
    map_.config = config
    return Response(map_._repr_html_(), mimetype='text/html')

# === Filtered clinic-only map ===
@app.route('/map/clinic')
def map_clinic():
    df = pd.read_sql(query, engine)
    clinic_df = df[df['amenity'].str.lower() == 'clinic']  # Filter for clinics only
    map_ = KeplerGl(height=600)
    map_.add_data(data=clinic_df, name='Clinics Only')
    map_.config = config
    return Response(map_._repr_html_(), mimetype='text/html')

# === Run Flask ===
def run_flask():
    app.run(debug=True, port=5006, use_reloader=False)

threading.Thread(target=run_flask).start()
# Out:
#  * Serving Flask app '__main__'
#  * Debug mode: on
# WARNING: This is a development server. Do not use it in a production deployment. Use a production WSGI server instead.
#  * Running on http://127.0.0.1:5006
# Press CTRL+C to quit
# 127.0.0.1 - - [11/Apr/2025 10:59:03] "GET / HTTP/1.1" 200 -
# User Guide: https://docs.kepler.gl/docs/keplergl-jupyter
# 127.0.0.1 - - [11/Apr/2025 10:59:04] "GET /map HTTP/1.1" 200 -
# 127.0.0.1 - - [11/Apr/2025 10:59:07] "GET /favicon.ico HTTP/1.1" 404 -
